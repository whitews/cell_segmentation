# %% [markdown]
# # Problem Introduction and data used

# %%
import os
os.chdir('..')

# %%
from utils.data import get_training_data_for_image_set, extract_contour_bounding_box_masked
from utils.visualize import display_instances_segments
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = get_training_data_for_image_set('data/image_set_90')

# %%
hsv_img = a['2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_003.tif']['hsv_img']
manual_contour = a['2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_003.tif']['regions'][2]

# %% [markdown]
# # Image

# %%
plt.imshow(cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB))

# %%
display_instances_segments(
    cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB),
    a['2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_003.tif']['regions'],
    ['raw']
)

# %% [markdown]
# ## Now, let's only one segment. First what does it look like up close?

# %%
sub = extract_contour_bounding_box_masked(
    cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB),
    a['2015-04-029_60X_C57Bl6_E16.5_LMM.14.24.4.46_SOX9_SFTPC_ACTA2_003.tif']['regions'][2]['points']
)
plt.imshow(sub)

# %% [markdown]
# > We will create one notebook from this point forward whose aim is to segment the cells in this segment as best possible. It's interesting to stop here and ask the question, **where would the expert human draw lines around all cells in this image?**
